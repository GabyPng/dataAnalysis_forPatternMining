# %% [markdown]
# # Facebook Live Sellers Thailand
#
# link: https://archive.ics.uci.edu/dataset/488/facebook+live+sellers+in+thailand
