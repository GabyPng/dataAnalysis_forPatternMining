# %% [markdown]
# # Agricultural Crop Yield Indian
#
# link: https://www.kaggle.com/datasets/akshatgupta7/crop-yield-in-indian-states-dataset
